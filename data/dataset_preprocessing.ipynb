# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud

# %%
df = pd.read_csv('./bbc.csv')

# %%
print(df.head())
# Out:
#                                                 text    labels  no_sentences  \
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business            26
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business            17
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business            14
# 3  High fuel prices hit BA's profits\n\nBritish A...  business            24
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business            17
#
#    Flesch Reading Ease Score  Dale-Chall Readability Score  \
# 0                      62.17                          9.72
# 1                      65.56                          9.09
# 2                      69.21                          9.66
# 3                      62.98                          9.86
# 4                      70.63                         10.23
#
#                                    text_rank_summary  \
# 0  It hopes to increase subscribers by offering t...
# ...

# %%
print(df.isnull().sum())
# Out:
# text                            0
# labels                          0
# no_sentences                    0
# Flesch Reading Ease Score       0
# Dale-Chall Readability Score    0
# text_rank_summary               0
# lsa_summary                     0
# dtype: int64

# %%
print(df['labels'].unique())
# Out:
# ['business' 'entertainment' 'politics' 'sport' 'tech']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.countplot(data=df, x='labels', palette='Set2')
plt.title('Number of Articles per Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-9ecdb93ca85b>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='labels', palette='Set2')

# %%
df = df.drop(columns=['no_sentences'])

# %%
df = df.drop(columns=['Flesch Reading Ease Score'])

# %%
df = df.drop(columns=['Dale-Chall Readability Score'])

# %%
df = df.drop(columns=['text_rank_summary'])

# %%
df = df.drop(columns=['lsa_summary'])

# %%
df.to_csv('news_data.csv', index=False)
